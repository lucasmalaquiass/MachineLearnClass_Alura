# %% [markdown]
# <a href="https://colab.research.google.com/github/lucasmalaquiass/MachineLearnClass_Alura/blob/main/FifthMachineLearnClass.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

uri = "https://gist.githubusercontent.com/guilhermesilveira/4d1d4a16ccbf6ea4e0a64a38a24ec884/raw/afd05cb0c796d18f3f5a6537053ded308ba94bf7/car-prices.csv"

dados = pd.read_csv(uri)
dados.head()
# Out:
#    Unnamed: 0  mileage_per_year  model_year      price sold
# 0           0             21801        2000   30941.02  yes
# 1           1              7843        1998   40557.96  yes
# 2           2              7109        2006   89627.50   no
# 3           3             26823        2015   95276.14   no
# 4           4              7935        2014  117384.68  yes

# %%
a_renomear = {
    "mileage_per_year" : "milhas_por_ano",
    "model_year" : "ano_do_modelo",
    "price" : "preco",
    "sold" : "vendido"
}
dados = dados.rename(columns=a_renomear)
dados.head()
# Out:
#    Unnamed: 0  milhas_por_ano  ano_do_modelo      preco vendido
# 0           0           21801           2000   30941.02     yes
# 1           1            7843           1998   40557.96     yes
# 2           2            7109           2006   89627.50      no
# 3           3           26823           2015   95276.14      no
# 4           4            7935           2014  117384.68     yes

# %%
venda = {
    "yes" : 1,
    "no" : 0
}

dados.vendido = dados.vendido.map(venda)
dados.head()
# Out:
#    Unnamed: 0  milhas_por_ano  ano_do_modelo      preco  vendido
# 0           0           21801           2000   30941.02        1
# 1           1            7843           1998   40557.96        1
# 2           2            7109           2006   89627.50        0
# 3           3           26823           2015   95276.14        0
# 4           4            7935           2014  117384.68        1

# %%
from datetime import datetime

ano_atual = datetime.today().year
dados["idade_do_modelo"] = ano_atual - dados.ano_do_modelo
dados.head()
# Out:
#    Unnamed: 0  milhas_por_ano  ano_do_modelo      preco  vendido  \
# 0           0           21801           2000   30941.02        1
# 1           1            7843           1998   40557.96        1
# 2           2            7109           2006   89627.50        0
# 3           3           26823           2015   95276.14        0
# 4           4            7935           2014  117384.68        1
#
#    idade_do_modelo
# 0               24
# 1               26
# 2               18
# 3                9
# 4               10

# %%
dados["km_por_ano"] = dados.milhas_por_ano *1.60934
dados.head()
# Out:
#    Unnamed: 0  milhas_por_ano  ano_do_modelo      preco  vendido  \
# 0           0           21801           2000   30941.02        1
# 1           1            7843           1998   40557.96        1
# 2           2            7109           2006   89627.50        0
# 3           3           26823           2015   95276.14        0
# 4           4            7935           2014  117384.68        1
#
#    idade_do_modelo   km_por_ano
# 0               24  35085.22134
# 1               26  12622.05362
# 2               18  11440.79806
# 3                9  43167.32682
# 4               10  12770.11290

# %%
dados = dados.drop(columns = ["Unnamed: 0", "milhas_por_ano", "ano_do_modelo"], axis = 1)
dados.head()
# Out:
#        preco  vendido  idade_do_modelo   km_por_ano
# 0   30941.02        1               24  35085.22134
# 1   40557.96        1               26  12622.05362
# 2   89627.50        0               18  11440.79806
# 3   95276.14        0                9  43167.32682
# 4  117384.68        1               10  12770.11290

# %%
import numpy as np
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score

x = dados[["preco", "idade_do_modelo", "km_por_ano"]]
y = dados["vendido"]

SEED = 5
np.random.seed(SEED)

treino_x, teste_x, treino_y, teste_y = train_test_split(x, y, test_size = 0.25,
                                                        stratify = y)
print(treino_x.shape)
print(teste_x.shape)
print("Treinaremos com %d elementos e testaremos com %d elementos" % (len(treino_x), len(teste_x)))

modelo = SVC()
modelo.fit(treino_x, treino_y)
previsoes = modelo.predict(teste_x)

acuracia = accuracy_score(teste_y, previsoes) * 100
print("A acurácia foi %.2f%%" % acuracia)
# Out:
# (7500, 3)
# (2500, 3)
# Treinaremos com 7500 elementos e testaremos com 2500 elementos
# A acurácia foi 78.28%

# %%
from sklearn.dummy import DummyClassifier
dummy_stratified = DummyClassifier()

dummy_stratified.fit(treino_x, treino_y)
acuracia = dummy_stratified.score(teste_x, teste_y) *100

#acuracia = accuracy_score(teste_y, previsoes) * 100
print("A acurácia foi %.2f%%" % acuracia)
# Out:
# A acurácia foi 58.00%

# %%
from sklearn.dummy import DummyClassifier
dummy_mostfrequent = DummyClassifier()

dummy_mostfrequent.fit(treino_x, treino_y)
acuracia = dummy_mostfrequent.score(teste_x, teste_y) * 100

print("A acurácia foi %.2f%%" % acuracia)
# Out:
# A acurácia foi 58.00%

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score

SEED = 5
np.random.seed(SEED)

cru_treino_x, cru_teste_x, treino_y, teste_y = train_test_split(x, y, test_size = 0.25,
                                                        stratify = y)
print(treino_x.shape)
print(teste_x.shape)
print("Treinaremos com %d elementos e testaremos com %d elementos" % (len(treino_x), len(teste_x)))

scaler = StandardScaler()
scaler.fit(cru_treino_x)
treino_x = scaler.transform(cru_treino_x)
teste_x = scaler.transform(cru_teste_x)

modelo = SVC()
modelo.fit(treino_x, treino_y)
previsoes = modelo.predict(teste_x)

acuracia = accuracy_score(teste_y, previsoes) * 100

print("A acurácia foi %.2f%%" % acuracia)
# Out:
# (7500, 3)
# (2500, 3)
# Treinaremos com 7500 elementos e testaremos com 2500 elementos
# A acurácia foi 77.48%
